# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/머신러닝1/조별활동/와인품질분류/data
# Out:
# /content/drive/MyDrive/Colab Notebooks/머신러닝1/조별활동/와인품질분류/data

# %%
train = pd.read_csv('train.csv', index_col=0)
test = pd.read_csv('test.csv', index_col=0)

# %%
test
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# index
# 0                9.0              0.31         0.48            6.60
# 1               13.3              0.43         0.58            1.90
# 2                6.5              0.28         0.27            5.20
# 3                7.2              0.15         0.39            1.80
# 4                6.8              0.26         0.26            2.00
# ...              ...               ...          ...             ...
# 995              7.1              0.59         0.02            2.30
# 996              8.7              0.15         0.30            1.60
# 997              8.8              0.66         0.26            1.70
# 998              7.0              0.42         0.19            2.30
# 999              8.5              0.21         0.26            9.25
#
#        chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# index
# 0          0.043                 11.0                  73.0  0.99380  2.90
# 1          0.070                 15.0                  40.0  1.00040  3.06
# 2          0.040                 44.0                 179.0  0.99480  3.19
# 3          0.043                 21.0                 159.0  0.99480  3.52
# 4          0.019                 23.5                  72.0  0.99041  3.16
# ...          ...                  ...                   ...      ...   ...
# 995        0.082                 24.0                  94.0  0.99744  3.55
# 996        0.046                 29.0                 130.0  0.99420  3.22
# 997        0.074                  4.0                  23.0  0.99710  3.15
# 998        0.071                 18.0                  36.0  0.99476  3.39
# 999        0.034                 73.0                 142.0  0.99450  3.05
#
#        sulphates  alcohol   type
# index
# 0           0.38     11.6  white
# 1           0.49      9.0    red
# 2           0.69      9.4  white
# 3           0.47     10.0  white
# 4           0.47     11.8  white
# ...          ...      ...    ...
# 995         0.53      9.7    red
# 996         0.38      9.8  white
# 997         0.74      9.2    red
# 998         0.56     10.9    red
# 999         0.37     11.4  white
#
# [1000 rows x 12 columns]

# %% [markdown]
# # 전처리

# %% [markdown]
# # label_encoder

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
label_encoder.fit(train['type'])
train['type'] = label_encoder.transform(train['type'])
test['type'] = label_encoder.transform(test['type'])

# %% [markdown]
# ## upsampling

# %%
from imblearn.over_sampling import SMOTE

# %%
X = train.drop('quality', axis=1)  # 입력 변수
y = train['quality']  # 타겟 변수

smote = SMOTE(k_neighbors=4)
X_resampled, y_resampled = smote.fit_resample(X, y)


train_resampled = pd.concat([X_resampled, y_resampled], axis=1)
train_resampled
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0           5.600000          0.695000     0.060000        6.800000
# 1           8.800000          0.610000     0.140000        2.400000
# 2           7.900000          0.210000     0.390000        2.000000
# 3           7.000000          0.210000     0.310000        6.000000
# 4           7.800000          0.400000     0.260000        9.500000
# ...              ...               ...          ...             ...
# 16907       8.181056          0.303082     0.391188        7.291801
# 16908       7.044051          0.287974     0.448038        2.759490
# 16909       8.070044          0.251824     0.395473        5.389635
# 16910       6.992781          0.337732     0.343711        3.791762
# 16911       6.915380          0.312693     0.317596        1.757690
#
#        chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# 0       0.042000             9.000000             84.000000  0.994320
# 1       0.067000            10.000000             42.000000  0.996900
# 2       0.057000            21.000000            138.000000  0.991760
# 3       0.046000            29.000000            108.000000  0.993900
# 4       0.059000            32.000000            178.000000  0.995500
# ...          ...                  ...                   ...       ...
# 16907   0.029854            26.529689            109.664471  0.994298
# 16908   0.028084            38.273364            114.678469  0.990160
# 16909   0.032577            27.394144            133.087846  0.993092
# 16910   0.020412            51.433118            122.711255  0.989939
# 16911   0.024942            25.182675            106.288150  0.990005
#
#              pH  sulphates    alcohol  type  quality
# 0      3.440000   0.440000  10.200000     1        5
# 1      3.190000   0.590000   9.500000     0        5
# 2      3.050000   0.520000  10.900000     1        5
# 3      3.260000   0.500000  10.800000     1        6
# 4      3.040000   0.430000  10.900000     1        6
# ...         ...        ...        ...   ...      ...
# 16907  3.277191   0.515137  11.135155     1        9
# 16908  3.344823   0.403215  12.844051     1        9
# 16909  3.248469   0.472117  11.672298     1        9
# 16910  3.280000   0.382268  12.662887     1        9
# 16911  3.358751   0.558751  12.439423     1        9
#
# [16912 rows x 13 columns]

# %% [markdown]
# # 모델링

# %% [markdown]
# ## ExtraTreesClassifier

# %%
y = train_resampled['quality'] #퀄리티 예측해야할거
X = train_resampled.drop('quality', axis=1) #예측해야할거빼고 나머지

# %%
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.model_selection import StratifiedShuffleSplit

# %%
model = ExtraTreesClassifier()

stratified_split = StratifiedShuffleSplit(n_splits=5, test_size=0.2, random_state=42)
# cv_accuracy = []

n_iter = 0
for train_idx, test_idx in stratified_split.split(X, y):
    X_train, X_val = X.iloc[train_idx], X.iloc[test_idx]
    y_train, y_val = y.iloc[train_idx], y.iloc[test_idx]

    #모델 학습
    model.fit(X_train, y_train)

y_pred=model.predict(test)

# %% [markdown]
# # 제출파일

# %%
submission = pd.read_csv('sample_submission.csv')

# %%
submission
# Out:
#      index  quality
# 0        0        0
# 1        1        0
# 2        2        0
# 3        3        0
# 4        4        0
# ..     ...      ...
# 995    995        0
# 996    996        0
# 997    997        0
# 998    998        0
# 999    999        0
#
# [1000 rows x 2 columns]

# %%
submission['quality'] = y_pred

# %%
submission.to_csv('upsampling_ExtraTree.csv', index=False)
